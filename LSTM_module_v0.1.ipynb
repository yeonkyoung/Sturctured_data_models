# %%
#-*-coding:utf-8-*-
import pandas as pd
import numpy as np
from pandas import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
import tensorflow as tf
from datetime import timedelta
import autokeras as ak
from kerastuner import HyperModel
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.models import load_model
from pmdarima import model_selection
from openpyxl import Workbook, drawing
# #만든 모듈을 불러옴
# import sys
# from importlib import reload
# sys.path.append('Desktop/2021 AI 빅데이터팀/메탈 수요예측/code/') # 모듈 저장 위치 지정
# print(sys.path)
# import Timeseries_module_ykkim as tsm
# Out:
# <ipython-input-201-45142b12db65>:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
# wb = openpyxl.Workbook()
# sheet1 = wb['Sheet']
# sheet1.title = '수집 데이터'#sheet name변경
# sheet1['A1'] = '첫번째 시트' #

# sheet2 = wb.create_sheet('정리 결과')
# sheet2.cell(row=1, column=1).value = '두번째 시트'

# sheet1.append(['다시', '첫번째 시트'])  #for문 안에서 돌아야함


# wb.save('C:/Users/KIMYEONKYOUNG/Desktop/2021 AI 빅데이터팀/메탈 수요예측/data/dd.xlsx')

# %%
def result_input(wb,model_root,test_h,col,com_col,output,pre_graph,loss_graph):
    sheet1 = wb.active
    sheet1.cell(row=1, column=2).value = col
    sheet1.cell(row=2, column=2).value = model_root
    sheet1.cell(row=4, column=1).value = output.index[0]
    sheet1.cell(row=3, column=2).value = col
    sheet1.cell(row=4, column=2).value = output[col][0]
    sheet1.cell(row=3, column=3).value = 'prediction'
    sheet1.cell(row=4, column=3).value = output['prediction'][0]
    sheet1.cell(row=3, column=4).value = com_col
    sheet1.cell(row=4, column=4).value = output[com_col][0]
    #graph import
    loss=drawing.image.Image(loss_graph)
    sheet1.add_image(loss,'A7')
    pre=drawing.image.Image(pre_graph)
    sheet1.add_image(pre,'A15')
    return sheet1

# %%
# class ts_data:
#     def __init__(self):
#         self.data=
#         self.columns=
        
        
#     def

# %%
#data to timeseries data 
def data2tsdata(raw_data,col):  #column은 '' 사용하여 입력
    
#     data['MM']=data['MONTH'].str.replace('월','')
    raw_data['MONTH']=raw_data['MONTH'].astype(str)
    raw_data['YEAR']=raw_data['YEAR'].astype(str)
    raw_data['Time']=raw_data['YEAR']+data['MONTH'] #data['MM']
    raw_data['Time']=raw_data['Time'].apply(lambda x: datetime.strptime(x, '%Y%m'))
    ts=raw_data[['Time',col]]
    ts_data=ts.set_index('Time')

    return ts_data.dropna()

# %%
# scalers
def standardscale(ts_data):
    scal = StandardScaler()
    dd_t = scal.fit_transform(ts_data)
    data_t = pd.DataFrame(dd_t,index=ts_data.index)
    return (data_t,scal)

def minmaxscale(ts_data):
    scal = MinMaxScaler()
    dd_t = scal.fit_transform(ts_data)
    data_t = pd.DataFrame(dd_t,index=ts_data.index)
    return (data_t,scal)
    
def robustscale(ts_data):
    scal = RobustScaler()
    dd_t = scal.fit_transform(ts_data)
    data_t = pd.DataFrame(dd_t,index=ts_data.index)
    return (data_t,scal)

# %%
#train_test split
def train_test_split(data_t,test_h,n_steps): #,val_h 
    test_cutoff_date= data_t.index.max() - timedelta(days=test_h*n_steps*28) 
#     val_cutoff_date=data_t.index.max() - timedelta(days=2*val_h*30) 
    df_test = data_t[data_t.index >=  test_cutoff_date ]
#     df_val = data_t[(data_t.index > val_cutoff_date) & (data_t.index <= test_cutoff_date)]
    df_train = data_t[(data_t.index < test_cutoff_date)]  #val_cutoff_date
    return (df_train,df_test) #,df_val

# %%
#preprocessing of LSTM
def split_sequence(sequence, n_steps:int):  #:ndarray   ,   ->(ndarray, ndarray)
    x = []
    y = [] 
    for i in range(len(sequence)):
        if(i+n_steps>=len(sequence)):
            break 
        x.append(sequence[i:i+n_steps]) 
        y.append(sequence[i+n_steps]) 
    return (np.asarray(x), np.asarray(y))

# %%
# build model
# class LSTM_model() :
n_steps=5
simple_lstm_model = tf.keras.models.Sequential([
tf.keras.layers.LSTM(10, activation = 'relu', input_shape=(n_steps,1),return_sequences=True),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.LSTM(20, activation = 'relu', input_shape=(n_steps,1),return_sequences=True),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.LSTM(10, activation = 'relu', input_shape=(n_steps,1)), 
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(5),   
tf.keras.layers.Dense(1)])

# %%
def visualize_loss(history, title,saveroot):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(saveroot+'lossgraph.png')
    return plt.show()

# %%
def predict_graph(train,test,prediction,plan,saveroot) :
    plt.figure(figsize=(8,5))
    kws = dict(marker='o')
    plt.plot(train, label='Train', **kws)   
    
    plt.plot(test, label='Test', **kws)   
    plt.plot(prediction,label='predicted', **kws)
    plt.plot(plan,label='plan', **kws)
    plt.legend()
    plt.savefig(saveroot+'_timeseries.png')
    return plt.show()

# %%
##################MAIN############################

#모델 학습(LSTM) & 평가
def LSTM_uni_train(raw_data,col,com_col,scale,n_steps,n_features,test_h,model,BATCH_SIZE=1,BUFFER_SIZE=100,EVALUATION_INTERVAL = 100,EPOCHS = 1000,optimizer='adam',loss='mse',metrics=['mse'],saveroot='C:/Users/KIMYEONKYOUNG/Desktop/2021 AI 빅데이터팀/메탈 수요예측/code/model_회사별/'):  #scaleoption : None,standard,minmax,robust # n_features = 1 (univariate) 
    
    #raw data 2 time series data
    ts_data=data2tsdata(raw_data,col)
    
    #scaling
    if scale == None :
        data_t = ts_data
    if scale == 'standard':
        (data_t,scal) = standardscale(ts_data)
    if scale == 'minmax':
        (data_t,scal) = minmaxscale(ts_data)
    if scale == 'robust':
        (data_t,scal) = robustscale(ts_data)
    
    #get train data
    (df_train,df_test) = train_test_split(data_t,test_h,n_steps)
    # [train] dateaframe to tensor 
    nd_train=np.asarray(df_train)
    nd_train=nd_train.reshape(len(df_train),)
    nd_test=np.asarray(df_test)
    nd_test=nd_test.reshape(len(df_test),)
    
    (train_x, train_y) = split_sequence(nd_train, n_steps) 
    train_x = train_x.reshape(train_x.shape[0], n_steps, n_features)
    
    #train data 2 train & val
    train_univariate = tf.data.Dataset.from_tensor_slices((train_x, train_y))
    train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
    val_univariate = tf.data.Dataset.from_tensor_slices((train_x, train_y))
    val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
    
    # Build EarlyStopping
    path_checkpoint = "lstm_model_checkpoint_try.h5"
    es_callback = tf.keras.callbacks.EarlyStopping(monitor="loss", min_delta=0, patience=100, mode='auto')# mode=auto loss면 최저값100번정도 반복되면 정지, acc면 최고값이 100번정도 반복되면 정지
    modelckpt_callback = tf.keras.callbacks.ModelCheckpoint(monitor="loss",filepath=path_checkpoint,verbose=1,save_weights_only=True,save_best_only=True,)
    
    model.compile(optimizer, loss , metrics)
    
    #train model
    history=model.fit(train_univariate,epochs=EPOCHS,validation_data=val_univariate,steps_per_epoch=EVALUATION_INTERVAL,validation_steps=1,verbose=1,callbacks=[es_callback, modelckpt_callback])
    
    #save model
    model.save(saveroot+'lstm_model_checkpoint_'+str(scale)+'_'+str(col)+'.h5')
    
    #graph
    visualize_loss(history, "Training & vaildation Loss",saveroot=saveroot)

    #########################################################################################
    #predict
    
    if test_h == 1 :
        xtt = nd_test.reshape(1, n_steps, n_features)
        #predict
        yhat = model.predict(xtt)
        prediction=pd.DataFrame(yhat)
        prediction.columns=['yhat']
        prediction.index=df_test[4:].index   
    
    if test_h != 1 :
        (xt, yt) = split_sequence(nd_test, n_steps)
        xtt = xt.reshape(xt.shape[0], n_steps, n_features)
        #predict
        yhat = model.predict(xtt)
        prediction=pd.DataFrame(yhat)
        prediction.columns=['yhat']
        prediction.index=df_test[n_step:].index   
    
    #inverse_scale
    prediction['prediction']=scal.inverse_transform(prediction)
    
    train_g, test_g = model_selection.train_test_split(ts_data, train_size=len(ts_data)-test_h)
    #outputdataframe(이동,실적,pred)
    outpu=pd.merge(test_g,prediction['prediction'],left_index=True, right_index=True)
    com_ts_data=data2tsdata(raw_data,com_col)
    output=pd.merge(outpu,com_ts_data,left_index=True, right_index=True)

    #timeseries graph(train,test,predict)    
    predict_graph(train_g,test_g,prediction['prediction'],output[com_col],saveroot=saveroot)

    
    #excel에 output저장(model_root, test_h, test_train loss, timeseries graph, output df)
    result_df=result_input(wb,model_root=saveroot+'lstm_model_checkpoint_'+str(scale)+'_'+str(col)+'.h5',test_h=test_h,col=col,com_col=com_col,output=output,pre_graph=saveroot+'_timeseries.png',loss_graph=saveroot+'lossgraph.png')

    return result_df

# %%
# #for graph (timeseries graph(train,test,predict),outputdataframe(이동,실적,pred),rmse,mse)
# def predict_model(modelroot,ts_data,df_test,test_h,n_step,n_features):
#     model=load_model(modelroot)
    
#     #test_df to array
#     ndt=np.asarray(df_test)
#     nddt=ndt.reshape(len(df_test),)
    
#     if predict_month == 1 :
#         xtt = nddt.reshape(1, n_steps, n_features)
#         #predict
#         yhat = model.predict(xtt)
#         prediction=pd.DataFrame(yhat)
#         prediction.columns=['yhat']
#         prediction.index=df_test[4:].index   
    
#     if predict_month != 1 :
#         (xt, yt) = split_sequence(nddt, n_steps)
#         xtt = xt.reshape(xt.shape[0], n_steps, n_features)
#         #predict
#         yhat = model.predict(xtt)
#         prediction=pd.DataFrame(yhat)
#         prediction.columns=['yhat']
#         prediction.index=df_test[n_step:].index   
    
#     #inverse_scale
    
#     prediction['prediction']=scal.inverse_transform(prediction)

#     #timeseries graph(train,test,predict)    
#     train_g, test_g = model_selection.train_test_split(ts_data, train_size=len(ts_data)-test_h)
#     pre_graph=predict_graph(train_g,test_g,prediction['prediction'])
    

#     #outputdataframe(이동,실적,pred)
#     output=pd.merge(test_g,prediction['prediction'],left_index=True, right_index=True)

#     return print(pre_graph),output

# %%
########module 실행

# %%
data=pd.read_excel('C:/Users/KIMYEONKYOUNG/Desktop/2021 AI 빅데이터팀/메탈 수요예측/data/pre_v0.1_합계제거.xlsx')

# %%
cc=list(data.columns)
train_col=[word for word in  cc if '_실적' in word]
com_col_list=[word for word in  cc if '_이동' in word]

# %%
wb = openpyxl.Workbook()
shh=LSTM_uni_train(raw_data=data,col='삼성전자_실적',com_col='삼성전자_이동',scale='minmax',test_h=1,n_steps=5,n_features=1,BATCH_SIZE=1,BUFFER_SIZE=100,model=simple_lstm_model,EVALUATION_INTERVAL = 100,EPOCHS = 1000,optimizer='adam',loss='mse',metrics=['mse'],saveroot='C:/Users/KIMYEONKYOUNG/Desktop/2021 AI 빅데이터팀/메탈 수요예측/code/model_회사별/')  #scaleoption : None,standard,minmax,robust # n_features = 1 (univariate)
# Out:
# Epoch 1/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0173 - mse: 0.0173WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x00000291B479A9D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100/100 [==============================] - 8s 16ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0556 - val_mse: 0.0556
#
# Epoch 00001: loss improved from inf to 0.01739, saving model to lstm_model_checkpoint_try.h5
# Epoch 2/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.0468 - val_mse: 0.0468
#
# Epoch 00002: loss did not improve from 0.01739
# Epoch 3/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0579 - val_mse: 0.0579s: 0.0132 - mse: 0.013
#
# Epoch 00003: loss did not improve from 0.01739
# Epoch 4/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0485 - val_mse: 0.0485
#
# Epoch 00004: loss improved from 0.01739 to 0.01292, saving model to lstm_model_checkpoint_try.h5
# Epoch 5/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0570 - val_mse: 0.0570
#
# Epoch 00005: loss did not improve from 0.01292
# Epoch 6/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00006: loss did not improve from 0.01292
# Epoch 7/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0542 - val_mse: 0.0542
#
# Epoch 00007: loss did not improve from 0.01292
# Epoch 8/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0625 - val_mse: 0.0625
#
# Epoch 00008: loss did not improve from 0.01292
# Epoch 9/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0554 - val_mse: 0.0554
#
# Epoch 00009: loss did not improve from 0.01292
# Epoch 10/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0709 - val_mse: 0.0709
#
# Epoch 00010: loss did not improve from 0.01292
# Epoch 11/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0673 - val_mse: 0.0673
#
# Epoch 00011: loss did not improve from 0.01292
# Epoch 12/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0516 - val_mse: 0.0516
#
# Epoch 00012: loss did not improve from 0.01292
# Epoch 13/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0478 - val_mse: 0.0478
#
# Epoch 00013: loss did not improve from 0.01292
# Epoch 14/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0561 - val_mse: 0.0561
#
# Epoch 00014: loss did not improve from 0.01292
# Epoch 15/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0257 - mse: 0.0257 - val_loss: 0.0519 - val_mse: 0.0519
#
# Epoch 00015: loss did not improve from 0.01292
# Epoch 16/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0572 - val_mse: 0.0572
#
# Epoch 00016: loss did not improve from 0.01292
# Epoch 17/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0600 - val_mse: 0.0600
#
# Epoch 00017: loss did not improve from 0.01292
# Epoch 18/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0568 - val_mse: 0.0568
#
# Epoch 00018: loss did not improve from 0.01292
# Epoch 19/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0639 - val_mse: 0.0639
#
# Epoch 00019: loss did not improve from 0.01292
# Epoch 20/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0543 - val_mse: 0.0543
#
# Epoch 00020: loss did not improve from 0.01292
# Epoch 21/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0574 - val_mse: 0.0574
#
# Epoch 00021: loss did not improve from 0.01292
# Epoch 22/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00022: loss improved from 0.01292 to 0.01136, saving model to lstm_model_checkpoint_try.h5
# Epoch 23/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00023: loss did not improve from 0.01136
# Epoch 24/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0543 - val_mse: 0.0543
#
# Epoch 00024: loss did not improve from 0.01136
# Epoch 25/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00025: loss did not improve from 0.01136
# Epoch 26/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0512 - val_mse: 0.0512
#
# Epoch 00026: loss did not improve from 0.01136
# Epoch 27/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0424 - val_mse: 0.0424
#
# Epoch 00027: loss did not improve from 0.01136
# Epoch 28/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00028: loss did not improve from 0.01136
# Epoch 29/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0561 - val_mse: 0.0561
#
# Epoch 00029: loss did not improve from 0.01136
# Epoch 30/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0527 - val_mse: 0.0527
#
# Epoch 00030: loss did not improve from 0.01136
# Epoch 31/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0546 - val_mse: 0.0546
#
# Epoch 00031: loss did not improve from 0.01136
# Epoch 32/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0432 - val_mse: 0.0432
#
# Epoch 00032: loss did not improve from 0.01136
# Epoch 33/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0485 - val_mse: 0.0485
#
# Epoch 00033: loss did not improve from 0.01136
# Epoch 34/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0461 - val_mse: 0.0461
#
# Epoch 00034: loss did not improve from 0.01136
# Epoch 35/1000
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0583 - val_mse: 0.0583
#
# Epoch 00035: loss did not improve from 0.01136
# Epoch 36/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0543 - val_mse: 0.0543
#
# Epoch 00036: loss did not improve from 0.01136
# Epoch 37/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0600 - val_mse: 0.0600
#
# Epoch 00037: loss did not improve from 0.01136
# Epoch 38/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0567 - val_mse: 0.0567
#
# Epoch 00038: loss did not improve from 0.01136
# Epoch 39/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0564 - val_mse: 0.0564
#
# Epoch 00039: loss did not improve from 0.01136
# Epoch 40/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0638 - val_mse: 0.0638
#
# Epoch 00040: loss did not improve from 0.01136
# Epoch 41/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0589 - val_mse: 0.0589
#
# Epoch 00041: loss did not improve from 0.01136
# Epoch 42/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0622 - val_mse: 0.0622
#
# Epoch 00042: loss did not improve from 0.01136
# Epoch 43/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00043: loss did not improve from 0.01136
# Epoch 44/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0650 - val_mse: 0.0650
#
# Epoch 00044: loss did not improve from 0.01136
# Epoch 45/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00045: loss did not improve from 0.01136
# Epoch 46/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00046: loss did not improve from 0.01136
# Epoch 47/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0419 - val_mse: 0.0419
#
# Epoch 00047: loss did not improve from 0.01136
# Epoch 48/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0526 - val_mse: 0.0526
#
# Epoch 00048: loss did not improve from 0.01136
# Epoch 49/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0481 - val_mse: 0.0481
#
# Epoch 00049: loss did not improve from 0.01136
# Epoch 50/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0570 - val_mse: 0.0570
#
# Epoch 00050: loss did not improve from 0.01136
# Epoch 51/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0581 - val_mse: 0.0581
#
# Epoch 00051: loss did not improve from 0.01136
# Epoch 52/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0541 - val_mse: 0.0541
#
# Epoch 00052: loss did not improve from 0.01136
# Epoch 53/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0107 - mse: 0.010 - 1s 10ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0555 - val_mse: 0.0555
#
# Epoch 00053: loss did not improve from 0.01136
# Epoch 54/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00054: loss did not improve from 0.01136
# Epoch 55/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0534 - val_mse: 0.0534
#
# Epoch 00055: loss did not improve from 0.01136
# Epoch 56/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00056: loss did not improve from 0.01136
# Epoch 57/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0473 - val_mse: 0.0473
#
# Epoch 00057: loss did not improve from 0.01136
# Epoch 58/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0372 - val_mse: 0.0372
#
# Epoch 00058: loss did not improve from 0.01136
# Epoch 59/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0563 - val_mse: 0.0563
#
# Epoch 00059: loss did not improve from 0.01136
# Epoch 60/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0559 - val_mse: 0.0559
#
# Epoch 00060: loss did not improve from 0.01136
# Epoch 61/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0520 - val_mse: 0.0520
#
# Epoch 00061: loss did not improve from 0.01136
# Epoch 62/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0446 - val_mse: 0.0446
#
# Epoch 00062: loss did not improve from 0.01136
# Epoch 63/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0631 - val_mse: 0.0631
#
# Epoch 00063: loss did not improve from 0.01136
# Epoch 64/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0580 - val_mse: 0.0580
#
# Epoch 00064: loss did not improve from 0.01136
# Epoch 65/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0559 - val_mse: 0.0559
#
# Epoch 00065: loss did not improve from 0.01136
# Epoch 66/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0523 - val_mse: 0.0523
#
# Epoch 00066: loss did not improve from 0.01136
# Epoch 67/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0464 - val_mse: 0.0464
#
# Epoch 00067: loss did not improve from 0.01136
# Epoch 68/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0554 - val_mse: 0.0554
#
# Epoch 00068: loss did not improve from 0.01136
# Epoch 69/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0535 - val_mse: 0.0535
#
# Epoch 00069: loss did not improve from 0.01136
# Epoch 70/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0530 - val_mse: 0.0530
#
# Epoch 00070: loss did not improve from 0.01136
# Epoch 71/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0603 - val_mse: 0.0603
#
# Epoch 00071: loss did not improve from 0.01136
# Epoch 72/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0442 - val_mse: 0.0442
#
# Epoch 00072: loss did not improve from 0.01136
# Epoch 73/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0596 - val_mse: 0.0596
#
# Epoch 00073: loss did not improve from 0.01136
# Epoch 74/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0536 - val_mse: 0.0536
#
# Epoch 00074: loss did not improve from 0.01136
# Epoch 75/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0547 - val_mse: 0.0547
#
# Epoch 00075: loss did not improve from 0.01136
# Epoch 76/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0607 - val_mse: 0.0607
#
# Epoch 00076: loss did not improve from 0.01136
# Epoch 77/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0415 - val_mse: 0.0415
#
# Epoch 00077: loss did not improve from 0.01136
# Epoch 78/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0597 - val_mse: 0.0597
#
# Epoch 00078: loss did not improve from 0.01136
# Epoch 79/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0616 - val_mse: 0.0616
#
# Epoch 00079: loss did not improve from 0.01136
# Epoch 80/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0634 - val_mse: 0.0634
#
# Epoch 00080: loss improved from 0.01136 to 0.01089, saving model to lstm_model_checkpoint_try.h5
# Epoch 81/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0597 - val_mse: 0.0597
#
# Epoch 00081: loss did not improve from 0.01089
# Epoch 82/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0574 - val_mse: 0.0574
#
# Epoch 00082: loss did not improve from 0.01089
# Epoch 83/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0467 - val_mse: 0.0467
#
# Epoch 00083: loss did not improve from 0.01089
# Epoch 84/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0414 - val_mse: 0.0414
#
# Epoch 00084: loss did not improve from 0.01089
# Epoch 85/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0454 - val_mse: 0.0454
#
# Epoch 00085: loss improved from 0.01089 to 0.01075, saving model to lstm_model_checkpoint_try.h5
# Epoch 86/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00086: loss did not improve from 0.01075
# Epoch 87/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00087: loss did not improve from 0.01075
# Epoch 88/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00088: loss did not improve from 0.01075
# Epoch 89/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00089: loss did not improve from 0.01075
# Epoch 90/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0683 - val_mse: 0.0683
#
# Epoch 00090: loss did not improve from 0.01075
# Epoch 91/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0697 - val_mse: 0.0697
#
# Epoch 00091: loss did not improve from 0.01075
# Epoch 92/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0591 - val_mse: 0.0591
#
# Epoch 00092: loss did not improve from 0.01075
# Epoch 93/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00093: loss did not improve from 0.01075
# Epoch 94/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0456 - val_mse: 0.0456
#
# Epoch 00094: loss did not improve from 0.01075
# Epoch 95/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0617 - val_mse: 0.0617
#
# Epoch 00095: loss did not improve from 0.01075
# Epoch 96/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0576 - val_mse: 0.0576
#
# Epoch 00096: loss did not improve from 0.01075
# Epoch 97/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0570 - val_mse: 0.0570
#
# Epoch 00097: loss did not improve from 0.01075
# Epoch 98/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0454 - val_mse: 0.0454
#
# Epoch 00098: loss did not improve from 0.01075
# Epoch 99/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0603 - val_mse: 0.0603
#
# Epoch 00099: loss did not improve from 0.01075
# Epoch 100/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0555 - val_mse: 0.0555
#
# Epoch 00100: loss did not improve from 0.01075
# Epoch 101/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0386 - val_mse: 0.0386
#
# Epoch 00101: loss did not improve from 0.01075
# Epoch 102/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0529 - val_mse: 0.0529
#
# Epoch 00102: loss did not improve from 0.01075
# Epoch 103/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0510 - val_mse: 0.0510
#
# Epoch 00103: loss did not improve from 0.01075
# Epoch 104/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0681 - val_mse: 0.0681
#
# Epoch 00104: loss did not improve from 0.01075
# Epoch 105/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0650 - val_mse: 0.0650
#
# Epoch 00105: loss did not improve from 0.01075
# Epoch 106/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0427 - val_mse: 0.0427
#
# Epoch 00106: loss did not improve from 0.01075
# Epoch 107/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0520 - val_mse: 0.0520
#
# Epoch 00107: loss did not improve from 0.01075
# Epoch 108/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0570 - val_mse: 0.0570
#
# Epoch 00108: loss did not improve from 0.01075
# Epoch 109/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00109: loss did not improve from 0.01075
# Epoch 110/1000
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0527 - val_mse: 0.0527
#
# Epoch 00110: loss did not improve from 0.01075
# Epoch 111/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0555 - val_mse: 0.0555
#
# Epoch 00111: loss did not improve from 0.01075
# Epoch 112/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00112: loss did not improve from 0.01075
# Epoch 113/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0607 - val_mse: 0.0607
#
# Epoch 00113: loss did not improve from 0.01075
# Epoch 114/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0413 - val_mse: 0.0413
#
# Epoch 00114: loss did not improve from 0.01075
# Epoch 115/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0485 - val_mse: 0.0485
#
# Epoch 00115: loss did not improve from 0.01075
# Epoch 116/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0483 - val_mse: 0.0483
#
# Epoch 00116: loss did not improve from 0.01075
# Epoch 117/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0557 - val_mse: 0.0557
#
# Epoch 00117: loss did not improve from 0.01075
# Epoch 118/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0499 - val_mse: 0.0499
#
# Epoch 00118: loss did not improve from 0.01075
# Epoch 119/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0659 - val_mse: 0.0659
#
# Epoch 00119: loss did not improve from 0.01075
# Epoch 120/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0539 - val_mse: 0.0539
#
# Epoch 00120: loss did not improve from 0.01075
# Epoch 121/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0440 - val_mse: 0.0440
#
# Epoch 00121: loss did not improve from 0.01075
# Epoch 122/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0550 - val_mse: 0.0550
#
# Epoch 00122: loss did not improve from 0.01075
# Epoch 123/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0515 - val_mse: 0.0515
#
# Epoch 00123: loss did not improve from 0.01075
# Epoch 124/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0486 - val_mse: 0.0486
#
# Epoch 00124: loss did not improve from 0.01075
# Epoch 125/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0599 - val_mse: 0.0599
#
# Epoch 00125: loss did not improve from 0.01075
# Epoch 126/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0632 - val_mse: 0.0632
#
# Epoch 00126: loss did not improve from 0.01075
# Epoch 127/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0582 - val_mse: 0.0582
#
# Epoch 00127: loss improved from 0.01075 to 0.01018, saving model to lstm_model_checkpoint_try.h5
# Epoch 128/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0599 - val_mse: 0.0599
#
# Epoch 00128: loss did not improve from 0.01018
# Epoch 129/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0545 - val_mse: 0.0545
#
# Epoch 00129: loss did not improve from 0.01018
# Epoch 130/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0665 - val_mse: 0.0665
#
# Epoch 00130: loss did not improve from 0.01018
# Epoch 131/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0650 - val_mse: 0.0650
#
# Epoch 00131: loss did not improve from 0.01018
# Epoch 132/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0580 - val_mse: 0.0580
#
# Epoch 00132: loss did not improve from 0.01018
# Epoch 133/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0603 - val_mse: 0.0603
#
# Epoch 00133: loss did not improve from 0.01018
# Epoch 134/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0444 - val_mse: 0.0444
#
# Epoch 00134: loss did not improve from 0.01018
# Epoch 135/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0531 - val_mse: 0.0531
#
# Epoch 00135: loss did not improve from 0.01018
# Epoch 136/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0545 - val_mse: 0.0545
#
# Epoch 00136: loss did not improve from 0.01018
# Epoch 137/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0607 - val_mse: 0.0607
#
# Epoch 00137: loss did not improve from 0.01018
# Epoch 138/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0546 - val_mse: 0.0546
#
# Epoch 00138: loss did not improve from 0.01018
# Epoch 139/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0636 - val_mse: 0.0636
#
# Epoch 00139: loss did not improve from 0.01018
# Epoch 140/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0568 - val_mse: 0.0568
#
# Epoch 00140: loss did not improve from 0.01018
# Epoch 141/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0650 - val_mse: 0.0650
#
# Epoch 00141: loss did not improve from 0.01018
# Epoch 142/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00142: loss did not improve from 0.01018
# Epoch 143/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0443 - val_mse: 0.0443
#
# Epoch 00143: loss did not improve from 0.01018
# Epoch 144/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00144: loss did not improve from 0.01018
# Epoch 145/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0399 - val_mse: 0.0399
#
# Epoch 00145: loss did not improve from 0.01018
# Epoch 146/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00146: loss did not improve from 0.01018
# Epoch 147/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0478 - val_mse: 0.0478
#
# Epoch 00147: loss did not improve from 0.01018
# Epoch 148/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0582 - val_mse: 0.0582
#
# Epoch 00148: loss did not improve from 0.01018
# Epoch 149/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0611 - val_mse: 0.0611
#
# Epoch 00149: loss did not improve from 0.01018
# Epoch 150/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0608 - val_mse: 0.0608
#
# Epoch 00150: loss did not improve from 0.01018
# Epoch 151/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0614 - val_mse: 0.0614
#
# Epoch 00151: loss did not improve from 0.01018
# Epoch 152/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0608 - val_mse: 0.0608
#
# Epoch 00152: loss did not improve from 0.01018
# Epoch 153/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00153: loss did not improve from 0.01018
# Epoch 154/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0547 - val_mse: 0.0547
#
# Epoch 00154: loss did not improve from 0.01018
# Epoch 155/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0480 - val_mse: 0.0480
#
# Epoch 00155: loss did not improve from 0.01018
# Epoch 156/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0534 - val_mse: 0.0534
#
# Epoch 00156: loss did not improve from 0.01018
# Epoch 157/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0455 - val_mse: 0.0455
#
# Epoch 00157: loss did not improve from 0.01018
# Epoch 158/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0494 - val_mse: 0.0494
#
# Epoch 00158: loss did not improve from 0.01018
# Epoch 159/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0566 - val_mse: 0.0566
#
# Epoch 00159: loss did not improve from 0.01018
# Epoch 160/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0470 - val_mse: 0.0470
#
# Epoch 00160: loss did not improve from 0.01018
# Epoch 161/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0597 - val_mse: 0.0597
#
# Epoch 00161: loss did not improve from 0.01018
# Epoch 162/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0441 - val_mse: 0.0441
#
# Epoch 00162: loss did not improve from 0.01018
# Epoch 163/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0532 - val_mse: 0.0532
#
# Epoch 00163: loss improved from 0.01018 to 0.00848, saving model to lstm_model_checkpoint_try.h5
# Epoch 164/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0467 - val_mse: 0.0467
#
# Epoch 00164: loss did not improve from 0.00848
# Epoch 165/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0505 - val_mse: 0.0505
#
# Epoch 00165: loss did not improve from 0.00848
# Epoch 166/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0527 - val_mse: 0.0527
#
# Epoch 00166: loss did not improve from 0.00848
# Epoch 167/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0519 - val_mse: 0.0519
#
# Epoch 00167: loss did not improve from 0.00848
# Epoch 168/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00168: loss did not improve from 0.00848
# Epoch 169/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0575 - val_mse: 0.0575
#
# Epoch 00169: loss did not improve from 0.00848
# Epoch 170/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0526 - val_mse: 0.0526
#
# Epoch 00170: loss did not improve from 0.00848
# Epoch 171/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0563 - val_mse: 0.0563
#
# Epoch 00171: loss did not improve from 0.00848
# Epoch 172/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0639 - val_mse: 0.0639
#
# Epoch 00172: loss did not improve from 0.00848
# Epoch 173/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0569 - val_mse: 0.0569
#
# Epoch 00173: loss did not improve from 0.00848
# Epoch 174/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0457 - val_mse: 0.0457
#
# Epoch 00174: loss did not improve from 0.00848
# Epoch 175/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0445 - val_mse: 0.0445
#
# Epoch 00175: loss did not improve from 0.00848
# Epoch 176/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00176: loss did not improve from 0.00848
# Epoch 177/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0562 - val_mse: 0.0562
#
# Epoch 00177: loss did not improve from 0.00848
# Epoch 178/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0381 - val_mse: 0.0381
#
# Epoch 00178: loss did not improve from 0.00848
# Epoch 179/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0324 - val_mse: 0.0324
#
# Epoch 00179: loss did not improve from 0.00848
# Epoch 180/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0558 - val_mse: 0.0558
#
# Epoch 00180: loss did not improve from 0.00848
# Epoch 181/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0329 - val_mse: 0.0329
#
# Epoch 00181: loss did not improve from 0.00848
# Epoch 182/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0442 - val_mse: 0.0442
#
# Epoch 00182: loss did not improve from 0.00848
# Epoch 183/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0548 - val_mse: 0.0548
#
# Epoch 00183: loss did not improve from 0.00848
# Epoch 184/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0452 - val_mse: 0.0452
#
# Epoch 00184: loss did not improve from 0.00848
# Epoch 185/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0397 - val_mse: 0.0397
#
# Epoch 00185: loss did not improve from 0.00848
# Epoch 186/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0321 - val_mse: 0.0321
#
# Epoch 00186: loss did not improve from 0.00848
# Epoch 187/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0435 - val_mse: 0.0435
#
# Epoch 00187: loss did not improve from 0.00848
# Epoch 188/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0562 - val_mse: 0.0562
#
# Epoch 00188: loss did not improve from 0.00848
# Epoch 189/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0567 - val_mse: 0.0567
#
# Epoch 00189: loss did not improve from 0.00848
# Epoch 190/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0263 - val_mse: 0.0263
#
# Epoch 00190: loss did not improve from 0.00848
# Epoch 191/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0420 - val_mse: 0.0420
#
# Epoch 00191: loss did not improve from 0.00848
# Epoch 192/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0519 - val_mse: 0.0519
#
# Epoch 00192: loss did not improve from 0.00848
# Epoch 193/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0551 - val_mse: 0.0551
#
# Epoch 00193: loss did not improve from 0.00848
# Epoch 194/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0540 - val_mse: 0.0540
#
# Epoch 00194: loss did not improve from 0.00848
# Epoch 195/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0459 - val_mse: 0.0459
#
# Epoch 00195: loss did not improve from 0.00848
# Epoch 196/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0579 - val_mse: 0.0579
#
# Epoch 00196: loss did not improve from 0.00848
# Epoch 197/1000
# 100/100 [==============================] - ETA: 0s - loss: 0.0135 - mse: 0.013 - 1s 10ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0510 - val_mse: 0.0510
#
# Epoch 00197: loss did not improve from 0.00848
# Epoch 198/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0529 - val_mse: 0.0529
#
# Epoch 00198: loss did not improve from 0.00848
# Epoch 199/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0550 - val_mse: 0.0550
#
# Epoch 00199: loss did not improve from 0.00848
# Epoch 200/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0625 - val_mse: 0.0625
#
# Epoch 00200: loss did not improve from 0.00848
# Epoch 201/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0464 - val_mse: 0.0464
#
# Epoch 00201: loss did not improve from 0.00848
# Epoch 202/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0445 - val_mse: 0.0445
#
# Epoch 00202: loss did not improve from 0.00848
# Epoch 203/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0570 - val_mse: 0.0570
#
# Epoch 00203: loss did not improve from 0.00848
# Epoch 204/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0658 - val_mse: 0.0658
#
# Epoch 00204: loss did not improve from 0.00848
# Epoch 205/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0514 - val_mse: 0.0514
#
# Epoch 00205: loss did not improve from 0.00848
# Epoch 206/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0473 - val_mse: 0.0473
#
# Epoch 00206: loss did not improve from 0.00848
# Epoch 207/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0430 - val_mse: 0.0430
#
# Epoch 00207: loss did not improve from 0.00848
# Epoch 208/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0420 - val_mse: 0.0420
#
# Epoch 00208: loss did not improve from 0.00848
# Epoch 209/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00209: loss did not improve from 0.00848
# Epoch 210/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0574 - val_mse: 0.0574
#
# Epoch 00210: loss did not improve from 0.00848
# Epoch 211/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00211: loss did not improve from 0.00848
# Epoch 212/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0439 - val_mse: 0.0439
#
# Epoch 00212: loss did not improve from 0.00848
# Epoch 213/1000
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0605 - val_mse: 0.0605
#
# Epoch 00213: loss did not improve from 0.00848
# Epoch 214/1000
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0631 - val_mse: 0.0631
#
# Epoch 00214: loss did not improve from 0.00848
# Epoch 215/1000
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0533 - val_mse: 0.0533
#
# Epoch 00215: loss did not improve from 0.00848
# Epoch 216/1000
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0557 - val_mse: 0.0557
#
# Epoch 00216: loss did not improve from 0.00848
# Epoch 217/1000
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0478 - val_mse: 0.0478
#
# Epoch 00217: loss did not improve from 0.00848
# Epoch 218/1000
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0430 - val_mse: 0.0430
#
# Epoch 00218: loss did not improve from 0.00848
# Epoch 219/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0512 - val_mse: 0.0512
#
# Epoch 00219: loss did not improve from 0.00848
# Epoch 220/1000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0601 - val_mse: 0.0601
#
# Epoch 00220: loss did not improve from 0.00848
# Epoch 221/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0494 - val_mse: 0.0494
#
# Epoch 00221: loss did not improve from 0.00848
# Epoch 222/1000
# 100/100 [==============================] - 2s 15ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0529 - val_mse: 0.0529
#
# Epoch 00222: loss did not improve from 0.00848
# Epoch 223/1000
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0628 - val_mse: 0.0628
#
# Epoch 00223: loss did not improve from 0.00848
# Epoch 224/1000
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0477 - val_mse: 0.0477
#
# Epoch 00224: loss did not improve from 0.00848
# Epoch 225/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0610 - val_mse: 0.0610
#
# Epoch 00225: loss did not improve from 0.00848
# Epoch 226/1000
#  66/100 [==================>...........] - ETA: 0s - loss: 0.0100 - mse: 0.0100

# %%
wb.save('C:/Users/KIMYEONKYOUNG/Desktop/2021 AI 빅데이터팀/메탈 수요예측/data/test.xlsx')

# %%
####make for loop to all data

# %%
for col,com_col in train_col,co
# Out:
#             삼성전자_실적  prediction
# Time
# 2021-03-01  151.017  132.083328
